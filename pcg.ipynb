# %% [markdown]
# # # PCG - Estudo de Caso Duke Breast Cancer
# #
# # A pesquisa em oncologia tem se beneficiado imensamente da análise de dados clínicos e genômicos, permitindo avanços significativos na medicina personalizada. O câncer de mama, sendo um dos tipos mais incidentes globalmente, exige uma compreensão profunda de seus subtipos moleculares, estadiamento e resposta a tratamentos. O objetivo desta análise exploratória é investigar o conjunto de dados "Duke Breast Cancer" para identificar padrões clínicos relevantes, avaliar a qualidade dos dados disponíveis e estruturar uma base sólida para futuras modelagens preditivas e descobertas clínicas.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
df_breast_cancer = pd.read_csv('./Dataset/Clinical_and_Other_Features.csv', sep=';')

# %% [markdown]
# ## Governança e Qualidade dos Dados (Pergunta 4)
# #
# # A governança e a qualidade dos dados são pilares fundamentais na pesquisa médica. Decisões clínicas e algoritmos de predição baseados em dados incorretos ou incompletos podem levar a conclusões enviesadas e condutas inadequadas. Portanto, a primeira etapa da nossa jornada analítica consiste em uma rigorosa auditoria de qualidade. Iniciamos com a análise de inconsistências e a quantificação de dados ausentes (valores nulos), o que nos permitirá definir estratégias de mitigação seguras e clinicamente válidas.

# %%
relatorio_dados_nulos = (df_breast_cancer.isnull().sum() / len(df_breast_cancer)) * 100
display(relatorio_dados_nulos.sort_values(ascending=False).head(10))
# Out:
# Unnamed: 98                                   100.000000
# BIRADS DATA                                   100.000000
# Unnamed: 27                                    71.645022
# Unnamed: 94                                    71.103896
# Pathologic Response to Neoadjuvant Therapy     70.670996
# Unnamed: 9                                     70.670996
# Unnamed: 93                                    70.562771
# Tumor Response                                 66.017316
# Unnamed: 96                                    66.017316
# Unnamed: 59                                    66.017316
# dtype: float64
